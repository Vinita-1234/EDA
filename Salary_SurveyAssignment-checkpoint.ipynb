# %% [markdown]
# ## About Data
# Information is about Salary suvery.This information is about employees getting salary according to their position,seniority level and experience

# %% [markdown]
# ## Data Issues
#
# 1.Timestamp is datetime field but it is given object field
# 2.Some field have missing values filled by median
# 3.Some Numerical fields datatypes are object convert it float or int
# 4.Some Categorical fileds data is improper
# 5.Some Numerical fields data is improper

# %% [markdown]
# ## Import Required Libaray

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and view data

# %%
df = pd.read_csv('salary_survey.csv')

# %%
df
# Out:
#              Timestamp   Age  Gender              City  \
# 0     24-11-2020 11:14  26.0    Male            Munich
# 1     24-11-2020 11:14  26.0    Male            Berlin
# 2     24-11-2020 11:14  29.0    Male            Berlin
# 3     24-11-2020 11:15  28.0    Male            Berlin
# 4     24-11-2020 11:15  37.0    Male            Berlin
# 5     24-11-2020 11:15  32.0    Male            Berlin
# 6     24-11-2020 11:16  37.0    Male            Berlin
# 7     24-11-2020 11:16  24.0    Male            Berlin
# 8     24-11-2020 11:17  29.0    Male            Berlin
# 9     24-11-2020 11:17  35.0    Male            Berlin
# 10    24-11-2020 11:18  32.0  Female           Hamburg
# 11    24-11-2020 11:18   NaN    Male            Berlin
# 12    24-11-2020 11:18   NaN     NaN            Berlin
# 13    24-11-2020 11:18  34.0    Male            Berlin
# 14    24-11-2020 11:18  28.0    Male            Berlin
# 15    24-11-2020 11:18  31.0    Male         Wolfsburg
# 16    24-11-2020 11:18  29.0    Male           Hamburg
# 17    24-11-2020 11:19  41.0    Male            Berlin
# 18    24-11-2020 11:20  27.0    Male            Berlin
# 19    24-11-2020 11:20  34.0    Male            Berlin
# 20    24-11-2020 11:21  34.0    Male            Berlin
# 21    24-11-2020 11:21  34.0    Male            Berlin
# 22    24-11-2020 11:22  25.0    Male            Berlin
# 23    24-11-2020 11:23  59.0    Male            Berlin
# 24    24-11-2020 11:23  36.0    Male            Berlin
# 25    24-11-2020 11:25  38.0    Male            Berlin
# 26    24-11-2020 11:25  24.0    Male            Berlin
# 27    24-11-2020 11:25  37.0    Male            Berlin
# 28    24-11-2020 11:25   NaN    Male            Berlin
# 29    24-11-2020 11:26  40.0    Male            Berlin
# ...                ...   ...     ...               ...
# 1223  05-01-2021 23:03  45.0    Male            Munich
# 1224  05-01-2021 23:51  31.0    Male            Munich
# 1225  06-01-2021 21:20  24.0    Male            Berlin
# 1226  06-01-2021 21:36  27.0    Male            Munich
# 1227  06-01-2021 21:42  34.0    Male            Berlin
# 1228  07-01-2021 10:47  28.0    Male            Munich
# 1229  07-01-2021 14:37  25.0    Male            Berlin
# 1230  08-01-2021 00:38  35.0    Male         Karlsruhe
# 1231  08-01-2021 12:52   NaN     NaN            Munich
# 1232  08-01-2021 16:12  52.0    Male         Stuttgart
# 1233  08-01-2021 17:23  33.0  Female            Munich
# 1234  10-01-2021 22:31  26.0    Male  Saint-Petersburg
# 1235  10-01-2021 22:32  26.0    Male  Saint-Petersburg
# 1236  11-01-2021 12:12  39.0    Male            Berlin
# 1237  12-01-2021 12:48  37.0    Male            Berlin
# 1238  12-01-2021 22:22  27.0    Male         Frankfurt
# 1239  13-01-2021 23:42  38.0    Male            Munich
# 1240  14-01-2021 01:14  31.0  Female            Berlin
# 1241  15-01-2021 18:28  30.0    Male            Berlin
# 1242  16-01-2021 14:39  32.0    Male            Munich
# 1243  16-01-2021 19:35  32.0  Female            Munich
# 1244  16-01-2021 22:23  32.0    Male            Munich
# 1245  17-01-2021 13:22  28.0    Male            Berlin
# 1246  18-01-2021 09:51  38.0    Male            Berlin
# 1247  18-01-2021 11:50  34.0    Male            Zurich
# 1248  18-01-2021 15:05  31.0    Male            Berlin
# 1249  18-01-2021 17:46  33.0    Male            Berlin
# 1250  18-01-2021 23:20  39.0    Male            Munich
# 1251  19-01-2021 10:17  26.0    Male       Saarbrücken
# 1252  19-01-2021 12:01  26.0    Male            Berlin
#
#                                    Position  Total experience  \
# 0                          Software Engineer                5
# 1                          Backend Developer                7
# 2                          Software Engineer               12
# 3                         Frontend Developer                4
# 4                          Backend Developer               17
# 5                                     DevOps                5
# 6                         Frontend Developer                6
# 7                         Frontend Developer                5
# 8                          Backend Developer                8
# 9                          Software Engineer               15
# 10                             Data Engineer                2
# 11                         Software Engineer               25
# 12                         Software Engineer              NaN
# 13                         Software Engineer               14
# 14                          Designer (UI/UX)               11
# 15                         Backend Developer                5
# 16                         Backend Developer                7
# 17                           Product Manager               18
# 18                         Backend Developer                8
# 19                          Mobile Developer               11
# 20                                    DevOps               13
# 21                        Software Architect               15
# 22                         Software Engineer                5
# 23                         Backend Developer               30
# 24                         Software Engineer               17
# 25                                 Team Lead               18
# 26                                    DevOps                6
# 27                              Test manager                6
# 28                                    DevOps               14
# 29                           Product Manager               13
# ...                                      ...              ...
# 1223                       Software Engineer               20
# 1224                       Backend Developer               10
# 1225                      Frontend Developer                5
# 1226                       Software Engineer                7
# 1227                      Frontend Developer                6
# 1228                       Software Engineer                7
# 1229                             ML Engineer                5
# 1230                       Software Engineer               12
# 1231                                     NaN              NaN
# 1232                       Software Engineer              NaN
# 1233                             Testmanager               10
# 1234                         Project Manager                5
# 1235                         Project Manager                5
# 1236                             QA Engineer                7
# 1237                        Mobile Developer               15
# 1238                       Software Engineer                3
# 1239                            Data Analyst               16
# 1240                          Data Scientist                4
# 1241                                     SRE               10
# 1242                          ERP Consultant               10
# 1243                             QA Engineer                8
# 1244                       Software Engineer               10
# 1245                      Frontend Developer                5
# 1246                     Head of Engineering               18
# 1247                       Software Engineer                7
# 1248                       Backend Developer                9
# 1249  Researcher/ Consumer Insights Analyst                10
# 1250                   IT Operations Manager               15
# 1251                      Frontend Developer                7
# 1252                                  DevOps                2
#
#      Experience in Germany Seniority level                Main technology  \
# 0                        3          Senior                     TypeScript
# 1                        4          Senior                           Ruby
# 2                        6            Lead        Javascript / Typescript
# 3                        1          Junior                     Javascript
# 4                        6          Senior                        C# .NET
# 5                        1          Senior           AWS, GCP, Python,K8s
# 6                      0.4          Middle                     Javascript
# 7                        1          Senior                     Typescript
# 8                        2          Senior                            PHP
# 9                        3            Lead                           Java
# 10                       2          Junior  Aws Hadoop Postgre Typescript
# 11                      11          Senior                            C++
# 12                     NaN            Lead                            PHP
# 13                       5          Senior                     Typescript
# 14                       2          Senior                            NaN
# 15                       1          Senior                         Kotlin
# 16                       3          Middle                           Ruby
# 17                       2          Senior                            NaN
# 18                       3          Senior                            PHP
# 19                       5            Lead                         kotlin
# 20                       5          Senior                            NaN
# 21                       9            Lead                         NodeJS
# 22                       2          Senior                     Javascript
# 23                      30          Senior                           Java
# 24                       2            Lead                            PHP
# 25                       4            Lead                            iOS
# 26                       3          Senior                     Kubernetes
# 27                       6          Middle                        Charles
# 28                       5          Senior                            NaN
# 29                       1          Senior                            SQL
# ...                    ...             ...                            ...
# 1223                    20   Self employed     .net, c++, spss, embeddded
# 1224                     7          Senior                  Ruby on Rails
# 1225                     2          Senior                     TypeScript
# 1226                     4          Middle                           .NET
# 1227                     2          Middle                     Javascript
# 1228                     3          Middle                           Java
# 1229                   0,5          Middle                          Scala
# 1230                     7          Senior                  .Net, Angular
# 1231                   NaN             NaN                            NaN
# 1232                    30            Lead                 Atlassian JIRA
# 1233                     2          Junior                           Java
# 1234                   NaN          Middle                         Python
# 1235                   NaN          Middle                         Python
# 1236                     5          Senior                           Java
# 1237                     5          Senior                        Android
# 1238                     1          Middle                           Qlik
# 1239                     4          Senior                            NaN
# 1240                     3          Middle                          spark
# 1241                     5             NaN                     Kubernetes
# 1242                     6            Lead                            SAP
# 1243                     5          Senior                           Java
# 1244                     5            Head                          Scala
# 1245                     5          Middle                     JavaScript
# 1246                     8            Head                            NaN
# 1247                     2          Senior                            PHP
# 1248                     5          Senior                           Java
# 1249                   1.5          Senior              consumer analysis
# 1250                     2            Lead                            PHP
# 1251                     7          Middle                     JavaScript
# 1252                     2          Middle                           yaml
#
#       Annual Salary in EUR Bonus in EUR Number of vacation days  \
# 0                  80000.0         5000                      30
# 1                  80000.0          NaN                      28
# 2                 120000.0       120000                      30
# 3                  54000.0          NaN                      24
# 4                  62000.0          NaN                      29
# 5                  76000.0         5000                      30
# 6                  57000.0          NaN                      24
# 7                  65000.0          NaN                      27
# 8                  56000.0          NaN                      28
# 9                  95000.0          NaN                      30
# 10                 52500.0          NaN                      30
# 11                100000.0          101                      24
# 12                 90000.0        40000                     NaN
# 13                 70000.0          NaN                      28
# 14                 75000.0         9400                      30
# 15                 75000.0         2000                      25
# 16                 60350.0          NaN                      31
# 17                 78000.0          NaN                      28
# 18                 60000.0          NaN                      25
# 19                 80000.0        80000                      28
# 20                103000.0          NaN                      30
# 21                100000.0          NaN                      24
# 22                 65000.0          NaN                      28
# 23                 69000.0          NaN                      28
# 24                 70000.0          NaN                      28
# 25                 80000.0         4000                      28
# 26                 75000.0        10000                      27
# 27                 47400.0         1000                      28
# 28                 67000.0         7000                      30
# 29                 70000.0          NaN                      28
# ...                    ...          ...                     ...
# 1223              200000.0        15000                      30
# 1224               85000.0        85000                      27
# 1225               68250.0            0                      27
# 1226               63000.0          NaN                      30
# 1227               63000.0            0                      25
# 1228               63000.0         4000                      30
# 1229               65000.0         2000                      30
# 1230               75000.0          NaN                      28
# 1231               70000.0          NaN                     NaN
# 1232              100000.0          NaN                     NaN
# 1233               60000.0        60000                      30
# 1234               20000.0         2000                      24
# 1235               20000.0         2000                      24
# 1236               76000.0         3000                      30
# 1237               84700.0         1000                      29
# 1238               52000.0          NaN                      27
# 1239               95000.0       105000                      30
# 1240               50500.0          NaN                      30
# 1241               68000.0          NaN                      26
# 1242              130000.0          NaN                      30
# 1243               55000.0          NaN                     NaN
# 1244               95000.0            0                      24
# 1245               55000.0          NaN                      30
# 1246               90000.0        20000                      26
# 1247              108500.0          NaN                      25
# 1248               70000.0        72000                      26
# 1249               60000.0         3000              unlimited
# 1250              110000.0            0                      28
# 1251               38350.0        40950                      27
# 1252               65000.0         6500                      30
#
#                Employment status   Contract duration Main language at work  \
# 0             Full-time employee  Unlimited contract               English
# 1             Full-time employee  Unlimited contract               English
# 2     Self-employed (freelancer)  Temporary contract               English
# 3             Full-time employee  Unlimited contract               English
# 4             Full-time employee  Unlimited contract               English
# 5             Full-time employee  Unlimited contract               English
# 6             Full-time employee  Unlimited contract               English
# 7             Full-time employee  Unlimited contract               English
# 8             Full-time employee  Unlimited contract               English
# 9             Full-time employee  Unlimited contract               English
# 10            Full-time employee  Unlimited contract                German
# 11    Self-employed (freelancer)  Temporary contract               English
# 12            Full-time employee  Unlimited contract               English
# 13            Full-time employee  Unlimited contract               English
# 14            Full-time employee  Unlimited contract               English
# 15            Full-time employee  Unlimited contract               English
# 16            Full-time employee  Unlimited contract               English
# 17            Full-time employee  Unlimited contract               English
# 18            Full-time employee  Unlimited contract               English
# 19            Full-time employee  Unlimited contract               English
# 20            Full-time employee  Unlimited contract               English
# 21            Full-time employee  Unlimited contract               English
# 22            Full-time employee  Unlimited contract                German
# 23            Full-time employee  Unlimited contract                German
# 24            Full-time employee  Unlimited contract               English
# 25            Full-time employee  Unlimited contract               English
# 26            Full-time employee  Unlimited contract               English
# 27            Full-time employee  Unlimited contract                German
# 28            Full-time employee  Unlimited contract               English
# 29            Full-time employee  Unlimited contract               English
# ...                          ...                 ...                   ...
# 1223  Self-employed (freelancer)                 NaN                German
# 1224          Full-time employee  Unlimited contract               English
# 1225          Full-time employee  Unlimited contract               English
# 1226          Full-time employee  Unlimited contract               English
# 1227          Full-time employee                 NaN               English
# 1228          Full-time employee  Unlimited contract               English
# 1229          Full-time employee  Unlimited contract               English
# 1230          Full-time employee  Unlimited contract               English
# 1231                         NaN                 NaN                   NaN
# 1232  Self-employed (freelancer)  Temporary contract               English
# 1233          Full-time employee  Unlimited contract                German
# 1234          Full-time employee  Unlimited contract               Russian
# 1235          Full-time employee  Unlimited contract               Russian
# 1236          Full-time employee  Unlimited contract               English
# 1237          Full-time employee  Unlimited contract               English
# 1238          Full-time employee  Unlimited contract                German
# 1239          Full-time employee  Unlimited contract               English
# 1240                         NaN  Unlimited contract               English
# 1241          Full-time employee  Unlimited contract               English
# 1242          Full-time employee  Unlimited contract               English
# 1243                         NaN                 NaN                German
# 1244          Full-time employee  Unlimited contract               English
# 1245          Full-time employee  Unlimited contract               English
# 1246          Full-time employee  Unlimited contract                German
# 1247          Full-time employee  Unlimited contract               English
# 1248          Full-time employee  Unlimited contract               English
# 1249          Full-time employee  Unlimited contract               English
# 1250          Full-time employee  Unlimited contract               English
# 1251          Full-time employee  Unlimited contract                German
# 1252          Full-time employee  Unlimited contract               English
#
#              Company type
# 0                 Product
# 1                 Product
# 2                 Product
# 3                 Startup
# 4                 Product
# 5                 Startup
# 6                 Product
# 7                 Product
# 8                 Product
# 9                 Product
# 10    Consulting / Agency
# 11                Product
# 12                    NaN
# 13                Startup
# 14                Product
# 15    Consulting / Agency
# 16                Product
# 17                Startup
# 18                Product
# 19                Product
# 20                Product
# 21                Product
# 22                Product
# 23                Product
# 24                Product
# 25                Product
# 26                Product
# 27                  Media
# 28                Product
# 29                Product
# ...                   ...
# 1223            freelance
# 1224              Startup
# 1225              Product
# 1226  Consulting / Agency
# 1227              Startup
# 1228              Product
# 1229              Product
# 1230              Product
# 1231                  NaN
# 1232  Consulting / Agency
# 1233              Product
# 1234              Product
# 1235              Product
# 1236              Product
# 1237              Product
# 1238              Product
# 1239              Product
# 1240              Product
# 1241              Product
# 1242              Product
# 1243              Product
# 1244              Startup
# 1245              Product
# 1246              Product
# 1247              Startup
# 1248              Product
# 1249              Product
# 1250            eCommerce
# 1251              Product
# 1252              Startup
#
# [1253 rows x 16 columns]

# %%
df.head()
# Out:
#           Timestamp   Age Gender    City           Position  Total experience  \
# 0  24-11-2020 11:14  26.0   Male  Munich   Software Engineer                5
# 1  24-11-2020 11:14  26.0   Male  Berlin   Backend Developer                7
# 2  24-11-2020 11:14  29.0   Male  Berlin   Software Engineer               12
# 3  24-11-2020 11:15  28.0   Male  Berlin  Frontend Developer                4
# 4  24-11-2020 11:15  37.0   Male  Berlin   Backend Developer               17
#
#   Experience in Germany Seniority level          Main technology  \
# 0                     3          Senior               TypeScript
# 1                     4          Senior                     Ruby
# 2                     6            Lead  Javascript / Typescript
# 3                     1          Junior               Javascript
# 4                     6          Senior                  C# .NET
#
#    Annual Salary in EUR Bonus in EUR Number of vacation days  \
# 0               80000.0         5000                      30
# 1               80000.0          NaN                      28
# 2              120000.0       120000                      30
# 3               54000.0          NaN                      24
# 4               62000.0          NaN                      29
#
#             Employment status   Contract duration Main language at work  \
# 0          Full-time employee  Unlimited contract               English
# 1          Full-time employee  Unlimited contract               English
# 2  Self-employed (freelancer)  Temporary contract               English
# 3          Full-time employee  Unlimited contract               English
# 4          Full-time employee  Unlimited contract               English
#
#   Company type
# 0      Product
# 1      Product
# 2      Product
# 3      Startup
# 4      Product

# %%
df.tail()
# Out:
#              Timestamp   Age Gender         City  \
# 1248  18-01-2021 15:05  31.0   Male       Berlin
# 1249  18-01-2021 17:46  33.0   Male       Berlin
# 1250  18-01-2021 23:20  39.0   Male       Munich
# 1251  19-01-2021 10:17  26.0   Male  Saarbrücken
# 1252  19-01-2021 12:01  26.0   Male       Berlin
#
#                                    Position  Total experience  \
# 1248                       Backend Developer                9
# 1249  Researcher/ Consumer Insights Analyst                10
# 1250                   IT Operations Manager               15
# 1251                      Frontend Developer                7
# 1252                                  DevOps                2
#
#      Experience in Germany Seniority level    Main technology  \
# 1248                     5          Senior               Java
# 1249                   1.5          Senior  consumer analysis
# 1250                     2            Lead                PHP
# 1251                     7          Middle         JavaScript
# 1252                     2          Middle               yaml
#
#       Annual Salary in EUR Bonus in EUR Number of vacation days  \
# 1248               70000.0        72000                      26
# 1249               60000.0         3000              unlimited
# 1250              110000.0            0                      28
# 1251               38350.0        40950                      27
# 1252               65000.0         6500                      30
#
#        Employment status   Contract duration Main language at work  \
# 1248  Full-time employee  Unlimited contract               English
# 1249  Full-time employee  Unlimited contract               English
# 1250  Full-time employee  Unlimited contract               English
# 1251  Full-time employee  Unlimited contract                German
# 1252  Full-time employee  Unlimited contract               English
#
#      Company type
# 1248      Product
# 1249      Product
# 1250    eCommerce
# 1251      Product
# 1252      Startup

# %%
df.shape
# Out:
# (1253, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 16 columns):
# Timestamp                  1253 non-null object
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# dtypes: float64(2), object(14)
# memory usage: 156.7+ KB

# %%
df.describe(include='all').T
# Out:
#                         count unique                 top  freq        mean  \
# Timestamp                1253   1026    24-11-2020 11:44     7         NaN
# Age                      1226    NaN                 NaN   NaN     32.5098
# Gender                   1243      3                Male  1049         NaN
# City                     1253    119              Berlin   681         NaN
# Position                 1247    148   Software Engineer   387         NaN
# Total experience         1237     48                  10   138         NaN
# Experience in Germany    1221     53                   2   195         NaN
# Seniority level          1241     24              Senior   565         NaN
# Main technology          1126    256                Java   184         NaN
# Annual Salary in EUR     1253    NaN                 NaN   NaN  8.0279e+07
# Bonus in EUR              829    168                   0   227         NaN
# Number of vacation days  1185     45                  30   488         NaN
# Employment status        1236     11  Full-time employee  1190         NaN
# Contract duration        1224      3  Unlimited contract  1159         NaN
# Main language at work    1237     14             English  1020         NaN
# Company type             1228     63             Product   760         NaN
#
#                                  std    min    25%    50%    75%    max
# Timestamp                        NaN    NaN    NaN    NaN    NaN    NaN
# Age                           5.6638     20     29     32     35     69
# Gender                           NaN    NaN    NaN    NaN    NaN    NaN
# City                             NaN    NaN    NaN    NaN    NaN    NaN
# Position                         NaN    NaN    NaN    NaN    NaN    NaN
# Total experience                 NaN    NaN    NaN    NaN    NaN    NaN
# Experience in Germany            NaN    NaN    NaN    NaN    NaN    NaN
# Seniority level                  NaN    NaN    NaN    NaN    NaN    NaN
# Main technology                  NaN    NaN    NaN    NaN    NaN    NaN
# Annual Salary in EUR     2.82506e+09  10001  58800  70000  80000  1e+11
# Bonus in EUR                     NaN    NaN    NaN    NaN    NaN    NaN
# Number of vacation days          NaN    NaN    NaN    NaN    NaN    NaN
# Employment status                NaN    NaN    NaN    NaN    NaN    NaN
# Contract duration                NaN    NaN    NaN    NaN    NaN    NaN
# Main language at work            NaN    NaN    NaN    NaN    NaN    NaN
# Company type                     NaN    NaN    NaN    NaN    NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 16 columns):
# Timestamp                  1253 non-null object
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# dtypes: float64(2), object(14)
# memory usage: 156.7+ KB

# %% [markdown]
# ## Data CleanUp

# %%
df['Total experience'].value_counts()
# Out:
# 10                                                     138
# 5                                                      136
# 6                                                       99
# 8                                                       92
# 7                                                       84
# 4                                                       80
# 12                                                      67
# 3                                                       66
# 15                                                      63
# 9                                                       60
# 2                                                       57
# 11                                                      43
# 13                                                      41
# 14                                                      39
# 1                                                       31
# 20                                                      28
# 16                                                      20
# 18                                                      16
# 17                                                      12
# 19                                                       7
# 25                                                       7
# 0                                                        6
# 22                                                       5
# 2.5                                                      4
# 30                                                       4
# 21                                                       3
# 23                                                       2
# 1,5                                                      2
# 4.5                                                      2
# 1.5                                                      2
# 3.5                                                      2
# 0.8                                                      2
# 27                                                       2
# 28                                                       1
# 24                                                       1
# 2,5                                                      1
# 31                                                       1
# less than year                                           1
# 7.5                                                      1
# 1 (as QA Engineer) / 11 in total                         1
# 26                                                       1
# 29                                                       1
# 15, thereof 8 as CTO                                     1
# 6 (not as a data scientist, but as a lab scientist)      1
# 6.5                                                      1
# 40                                                       1
# 5.5                                                      1
# 383                                                      1
# Name: Total experience, dtype: int64

# %%
df['TE']=df['Total experience'].str.split(' ').str[0]

# %%
df['TE'].value_counts()
# Out:
# 10      138
# 5       136
# 6       100
# 8        92
# 7        84
# 4        80
# 12       67
# 3        66
# 15       63
# 9        60
# 2        57
# 11       43
# 13       41
# 14       39
# 1        32
# 20       28
# 16       20
# 18       16
# 17       12
# 25        7
# 19        7
# 0         6
# 22        5
# 2.5       4
# 30        4
# 21        3
# 1,5       2
# 23        2
# 4.5       2
# 27        2
# 3.5       2
# 1.5       2
# 0.8       2
# 15,       1
# 5.5       1
# 40        1
# 26        1
# 29        1
# 7.5       1
# 6.5       1
# 31        1
# 28        1
# 2,5       1
# 24        1
# less      1
# 383       1
# Name: TE, dtype: int64

# %%
df[df['TE']==383]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, City, Position , Total experience, Experience in Germany, Seniority level, Main technology, Annual Salary in EUR, Bonus in EUR, Number of vacation days, Employment status, Contract duration, Main language at work, Company type, TE]
# Index: []

# %%
df['TE'].replace({'2,5':'2.5','1,5':'1.5','less':np.NaN,'5,2':'5.2'},inplace=True)

# %%
df['TE'].value_counts()
# Out:
# 10     138
# 5      136
# 6      100
# 8       92
# 7       84
# 4       80
# 12      67
# 3       66
# 15      63
# 9       60
# 2       57
# 11      43
# 13      41
# 14      39
# 1       32
# 20      28
# 16      20
# 18      16
# 17      12
# 25       7
# 19       7
# 0        6
# 2.5      5
# 22       5
# 30       4
# 1.5      4
# 21       3
# 23       2
# 4.5      2
# 27       2
# 3.5      2
# 0.8      2
# 6.5      1
# 7.5      1
# 28       1
# 31       1
# 26       1
# 29       1
# 5.5      1
# 40       1
# 24       1
# 15,      1
# 383      1
# Name: TE, dtype: int64

# %%
df['TE']=df['Total experience'].str.split(' ').str[0]

# %%
df['TE'].value_counts()
# Out:
# 10      138
# 5       136
# 6       100
# 8        92
# 7        84
# 4        80
# 12       67
# 3        66
# 15       63
# 9        60
# 2        57
# 11       43
# 13       41
# 14       39
# 1        32
# 20       28
# 16       20
# 18       16
# 17       12
# 25        7
# 19        7
# 0         6
# 22        5
# 2.5       4
# 30        4
# 21        3
# 1,5       2
# 23        2
# 4.5       2
# 27        2
# 3.5       2
# 1.5       2
# 0.8       2
# 15,       1
# 5.5       1
# 40        1
# 26        1
# 29        1
# 7.5       1
# 6.5       1
# 31        1
# 28        1
# 2,5       1
# 24        1
# less      1
# 383       1
# Name: TE, dtype: int64

# %%
df['TE'].replace({'2,5':'2.5','1,5':'1.5','less':np.NaN,'5,2':'5.2','15,':'15','383':'38'},inplace=True)

# %%
df['TE'].value_counts()
# Out:
# 10     138
# 5      136
# 6      100
# 8       92
# 7       84
# 4       80
# 12      67
# 3       66
# 15      64
# 9       60
# 2       57
# 11      43
# 13      41
# 14      39
# 1       32
# 20      28
# 16      20
# 18      16
# 17      12
# 25       7
# 19       7
# 0        6
# 2.5      5
# 22       5
# 30       4
# 1.5      4
# 21       3
# 23       2
# 4.5      2
# 27       2
# 3.5      2
# 0.8      2
# 7.5      1
# 6.5      1
# 38       1
# 28       1
# 31       1
# 26       1
# 29       1
# 5.5      1
# 40       1
# 24       1
# Name: TE, dtype: int64

# %%
df['TE'].head(50)
# Out:
# 0       5
# 1       7
# 2      12
# 3       4
# 4      17
# 5       5
# 6       6
# 7       5
# 8       8
# 9      15
# 10      2
# 11     25
# 12    NaN
# 13     14
# 14     11
# 15      5
# 16      7
# 17     18
# 18      8
# 19     11
# 20     13
# 21     15
# 22      5
# 23     30
# 24     17
# 25     18
# 26      6
# 27      6
# 28     14
# 29     13
# 30      6
# 31      5
# 32      7
# 33      8
# 34      8
# 35      5
# 36      7
# 37      8
# 38      5
# 39     10
# 40      7
# 41     15
# 42     10
# 43     12
# 44      6
# 45     25
# 46      5
# 47      3
# 48     12
# 49      7
# Name: TE, dtype: object

# %%
df['TE'].tail(30)
# Out:
# 1223     20
# 1224     10
# 1225      5
# 1226      7
# 1227      6
# 1228      7
# 1229      5
# 1230     12
# 1231    NaN
# 1232    NaN
# 1233     10
# 1234      5
# 1235      5
# 1236      7
# 1237     15
# 1238      3
# 1239     16
# 1240      4
# 1241     10
# 1242     10
# 1243      8
# 1244     10
# 1245      5
# 1246     18
# 1247      7
# 1248      9
# 1249     10
# 1250     15
# 1251      7
# 1252      2
# Name: TE, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 17 columns):
# Timestamp                  1253 non-null object
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1236 non-null object
# dtypes: float64(2), object(15)
# memory usage: 166.5+ KB

# %%
df['Timestamp'].value_counts()
# Out:
# 24-11-2020 11:44    7
# 24-11-2020 11:18    7
# 24-11-2020 11:32    5
# 24-11-2020 12:07    5
# 24-11-2020 12:09    5
# 24-11-2020 11:56    5
# 24-11-2020 11:30    5
# 24-11-2020 11:40    5
# 24-11-2020 11:31    5
# 24-11-2020 11:33    5
# 24-11-2020 12:28    5
# 24-11-2020 11:46    5
# 24-11-2020 11:50    5
# 24-11-2020 11:38    4
# 24-11-2020 12:14    4
# 24-11-2020 11:59    4
# 24-11-2020 11:55    4
# 25-11-2020 14:08    4
# 24-11-2020 14:34    4
# 24-11-2020 11:25    4
# 24-11-2020 12:17    4
# 24-11-2020 11:54    3
# 25-11-2020 14:37    3
# 24-11-2020 12:23    3
# 24-11-2020 17:29    3
# 25-11-2020 09:05    3
# 24-11-2020 12:55    3
# 24-11-2020 13:05    3
# 24-11-2020 12:21    3
# 24-11-2020 11:43    3
#                    ..
# 02-12-2020 00:27    1
# 30-11-2020 13:50    1
# 24-11-2020 19:47    1
# 04-12-2020 15:56    1
# 24-11-2020 14:52    1
# 25-11-2020 17:09    1
# 24-11-2020 20:01    1
# 30-11-2020 14:42    1
# 28-11-2020 19:42    1
# 20-12-2020 10:31    1
# 01-12-2020 14:58    1
# 27-11-2020 19:45    1
# 26-11-2020 08:39    1
# 29-11-2020 20:53    1
# 27-11-2020 14:08    1
# 01-12-2020 00:20    1
# 26-11-2020 23:34    1
# 24-11-2020 14:06    1
# 01-12-2020 14:33    1
# 25-11-2020 01:29    1
# 24-11-2020 12:11    1
# 30-11-2020 13:17    1
# 02-12-2020 21:53    1
# 30-11-2020 11:06    1
# 24-11-2020 19:48    1
# 25-11-2020 11:15    1
# 16-01-2021 22:23    1
# 24-11-2020 12:47    1
# 25-11-2020 06:05    1
# 25-11-2020 09:03    1
# Name: Timestamp, Length: 1026, dtype: int64

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 17 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1236 non-null object
# dtypes: datetime64[ns](1), float64(2), object(14)
# memory usage: 166.5+ KB

# %%
df.TE=df.TE.astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 17 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1236 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(13)
# memory usage: 166.5+ KB

# %%
df.TE.fillna(df.TE.median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 17 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(13)
# memory usage: 166.5+ KB

# %%
df['Experience in Germany'].value_counts()
# Out:
# 2                                                      195
# 1                                                      189
# 3                                                      155
# 5                                                      142
# 4                                                      122
# 0                                                       99
# 6                                                       70
# 7                                                       37
# 10                                                      29
# 1.5                                                     24
# 9                                                       20
# 8                                                       17
# 0.5                                                     13
# 12                                                      12
# 2.5                                                     10
# 3.5                                                      9
# 15                                                       8
# 20                                                       7
# 11                                                       7
# 14                                                       5
# 1,5                                                      5
# 0,5                                                      5
# 13                                                       4
# 30                                                       3
# 0.25                                                     2
# 2,5                                                      2
# 3,5                                                      2
# 18                                                       2
# 19                                                       2
# less than year                                           1
# 16                                                       1
# 0.4                                                      1
# 2.6                                                      1
# 4,5                                                      1
# 4 (in Switzerland), 0 (in Germany)                       1
# 0.9                                                      1
# 4.5                                                      1
# -                                                        1
# 3 (in Poland)                                            1
# 17                                                       1
# 4 month                                                  1
# 0,3                                                      1
# 3 months                                                 1
# < 1                                                      1
# 26                                                       1
# 25                                                       1
# 0.2                                                      1
# 0.1                                                      1
# <1                                                       1
# 6 (not as a data scientist, but as a lab scientist)      1
# ⁰                                                        1
# 0.8                                                      1
# 1,7                                                      1
# Name: Experience in Germany, dtype: int64

# %%
df['ExpGermany']=df['Experience in Germany'].str.split(' ').str[0]

# %%
df['ExpGermany'].value_counts()
# Out:
# 2       195
# 1       189
# 3       157
# 5       142
# 4       124
# 0        99
# 6        71
# 7        37
# 10       29
# 1.5      24
# 9        20
# 8        17
# 0.5      13
# 12       12
# 2.5      10
# 3.5       9
# 15        8
# 20        7
# 11        7
# 0,5       5
# 1,5       5
# 14        5
# 13        4
# 30        3
# 18        2
# 0.25      2
# 2,5       2
# 3,5       2
# 19        2
# 16        1
# 4,5       1
# 0.4       1
# 0.9       1
# 4.5       1
# 0,3       1
# 2.6       1
# -         1
# less      1
# 17        1
# 26        1
# 25        1
# 0.2       1
# 0.1       1
# <1        1
# <         1
# ⁰         1
# 0.8       1
# 1,7       1
# Name: ExpGermany, dtype: int64

# %%
df['ExpGermany'].replace({'0,5':'0.5','0,3':'0.3','1,5':'1.5','1,7':'1.7','less':np.NaN,'2,5':'2.5','3,5':'3.5','4,5':'4.5','<1':'1','<':np.NaN,'⁰':'0','-':np.NaN},inplace=True)

# %%
df['ExpGermany'].value_counts()
# Out:
# 2       195
# 1       190
# 3       157
# 5       142
# 4       124
# 0       100
# 6        71
# 7        37
# 1.5      29
# 10       29
# 9        20
# 0.5      18
# 8        17
# 2.5      12
# 12       12
# 3.5      11
# 15        8
# 11        7
# 20        7
# 14        5
# 13        4
# 30        3
# 0.25      2
# 18        2
# 4.5       2
# 19        2
# 26        1
# 0.3       1
# 2.6       1
# 25        1
# 0.2       1
# 0.1       1
# 0.8       1
# 16        1
# 1.7       1
# 17        1
# 0.4       1
# 0.9       1
# Name: ExpGermany, dtype: int64

# %%
df.ExpGermany.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 18 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null object
# dtypes: datetime64[ns](1), float64(3), object(14)
# memory usage: 176.3+ KB

# %%
df.ExpGermany=df.ExpGermany.astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 18 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null float64
# dtypes: datetime64[ns](1), float64(4), object(13)
# memory usage: 176.3+ KB

# %%
df['Bonus in EUR'].value_counts()
# Out:
# 0             227
# 5000           56
# 10000          45
# 2000           36
# 6000           26
# 1000           23
# 3000           23
# 20000          21
# 4000           18
# 15000          16
# 7000           15
# 8000           13
# 70000          11
# 75000          11
# 12000          11
# 30000           8
# 101             8
# 1500            7
# 40000           7
# 100000          7
# 60000           6
# 25000           6
# 50000           6
# 80000           6
# 55000           5
# 45000           5
# 65000           5
# 200000          5
# 7500            5
# 120000          5
#              ...
# 2400            1
# -               1
# 7300            1
# 12150           1
# 9450            1
# 3400            1
# 17800           1
# 5000000000      1
# 84000           1
# 450000          1
# 19200           1
# 86000           1
# 60847.32        1
# 10300           1
# 50400           1
# 6900            1
# 89000           1
# 35200           1
# 140000          1
# 20700           1
# 53500           1
# 66447           1
# 6300            1
# 82500           1
# 1250            1
# 3500            1
# 38500           1
# 74000           1
# 3250            1
# bvg only        1
# Name: Bonus in EUR, Length: 168, dtype: int64

# %%
pd.options.display.max_seq_items=250

# %%
df['Bonus in EUR'].value_counts()
# Out:
# 0             227
# 5000           56
# 10000          45
# 2000           36
# 6000           26
# 1000           23
# 3000           23
# 20000          21
# 4000           18
# 15000          16
# 7000           15
# 8000           13
# 70000          11
# 75000          11
# 12000          11
# 30000           8
# 101             8
# 1500            7
# 40000           7
# 100000          7
# 60000           6
# 25000           6
# 50000           6
# 80000           6
# 55000           5
# 45000           5
# 65000           5
# 200000          5
# 7500            5
# 120000          5
#              ...
# 2400            1
# -               1
# 7300            1
# 12150           1
# 9450            1
# 3400            1
# 17800           1
# 5000000000      1
# 84000           1
# 450000          1
# 19200           1
# 86000           1
# 60847.32        1
# 10300           1
# 50400           1
# 6900            1
# 89000           1
# 35200           1
# 140000          1
# 20700           1
# 53500           1
# 66447           1
# 6300            1
# 82500           1
# 1250            1
# 3500            1
# 38500           1
# 74000           1
# 3250            1
# bvg only        1
# Name: Bonus in EUR, Length: 168, dtype: int64

# %%
df['Bonus in EUR'].value_counts().index
# Out:
# Index(['0', '5000', '10000', '2000', '6000', '1000', '3000', '20000', '4000',
#        '15000', '7000', '8000', '70000', '75000', '12000', '30000', '101',
#        '1500', '40000', '100000', '60000', '25000', '50000', '80000', '55000',
#        '45000', '65000', '200000', '7500', '120000', '500', '35000', '11000',
#        '9000', '18000', '90000', '95000', '77000', '85000', '62000', '73000',
#        '150000', '4500', '17000', '2500', '78000', '99000', '16000', '72000',
#        '6500', '56000', '15900', '800', '13000', '14000', '7200', '7100',
#        '700', '66500', '47500', '22000', '23000', '31500', '67000', '16320',
#        '28800', 'depends', '45600', '20240', '11900', '4250', '14500', '43500',
#        '12500', '3800', '54000', '2800', '5500', '170000', '9400', '1150000',
#        '7750', '63000', '96000', '88000', '46000', '80400', '25', '70500',
#        '63909', '22500', '122.13', '32000', '92000', '97000', '112000',
#        '59000', '1200', '107000', '45500', '3520', '13500', '400', '21000',
#        '40950', '1100', '37968', '58000', 'Na', '43000', '71000', '125000',
#        '28000', '77400', '8500', '102600', '4700', '3375', '81200', '63500',
#        '5400', '15000+-', '5800', '12', '1600', '3600', 'Not sure', '5600',
#        '87250', '105000', '4300', '4400', '6710', '26000', '82000', '110000',
#        '36000', '106000', '2400', '-', '7300', '12150', '9450', '3400',
#        '17800', '5000000000', '84000', '450000', '19200', '86000', '60847.32',
#        '10300', '50400', '6900', '89000', '35200', '140000', '20700', '53500',
#        '66447', '6300', '82500', '1250', '3500', '38500', '74000', '3250',
#        'bvg only'],
#       dtype='object')

# %%
df['Bonus_EUR']=df['Bonus in EUR'].str.split(' ').str[0]

# %%
df['Bonus_EUR'].value_counts().index
# Out:
# Index(['0', '5000', '10000', '2000', '6000', '1000', '3000', '20000', '4000',
#        '15000', '7000', '8000', '75000', '12000', '70000', '30000', '101',
#        '100000', '40000', '1500', '50000', '80000', '25000', '60000', '120000',
#        '55000', '500', '65000', '7500', '45000', '200000', '90000', '77000',
#        '9000', '11000', '18000', '95000', '35000', '73000', '85000', '4500',
#        '17000', '150000', '62000', '72000', '800', '56000', '99000', '14000',
#        '13000', '16000', '78000', '6500', '2500', '15900', '7200', '11900',
#        '4400', '47500', '45600', '31500', 'depends', '7100', '67000', '14500',
#        '700', '22000', '16320', '23000', '28800', '4250', '43500', '46000',
#        '12500', '3800', '54000', '2800', '1150000', '5500', '170000', '9400',
#        '20240', '7750', '63000', '96000', '88000', '80400', '45500', 'bvg',
#        '25', '70500', '63909', '22500', '66500', '32000', '92000', '97000',
#        '112000', '59000', '1200', '107000', '122.13', '60847.32', '3520',
#        '110000', '40950', '1100', '37968', '58000', 'Na', '43000', '71000',
#        '125000', '28000', 'Not', '77400', '8500', '102600', '4700', '3375',
#        '21000', '81200', '5400', '15000+-', '5800', '12', '1600', '3600',
#        '5600', '87250', '105000', '4300', '6710', '26000', '82000', '36000',
#        '400', '106000', '63500', '2400', '-', '7300', '12150', '9450', '3400',
#        '17800', '5000000000', '84000', '450000', '19200', '86000', '10300',
#        '13500', '50400', '6900', '35200', '140000', '20700', '53500', '66447',
#        '6300', '82500', '1250', '3500', '38500', '74000', '3250', '89000'],
#       dtype='object')

# %%
df['Bonus_EUR'].replace({'depends':np.NaN,'15000+-':15000,'Na':np.NaN,'Not':np.NaN,'-':np.NaN,'bvg':np.NaN},inplace=True)

# %%
df['Bonus_EUR'].value_counts().index
# Out:
# Index([         '0',       '5000',      '10000',       '2000',       '6000',
#              '3000',       '1000',      '20000',       '4000',      '15000',
#              '7000',       '8000',      '70000',      '75000',      '12000',
#             '30000',        '101',       '1500',     '100000',      '40000',
#             '50000',      '25000',      '80000',      '60000',     '200000',
#              '7500',        '500',     '120000',      '55000',      '65000',
#             '45000',      '90000',      '35000',      '18000',      '95000',
#              '9000',      '77000',      '11000',      '73000',      '17000',
#            '150000',      '62000',      '85000',       '4500',      '13000',
#             '16000',      '78000',       '2500',      '72000',      '99000',
#             '14000',       '6500',        '800',      '15900',      '56000',
#              '7100',       '4250',      '20240',      '23000',      '67000',
#             '28800',      '47500',      '45600',      '31500',      '22000',
#              '7200',      '16320',      '11900',     '122.13',      '14500',
#             '80400',      '12500',       '3800',       '2800',       '5500',
#               '700',       '9400',    '1150000',       '7750',      '63000',
#             '96000',      '88000',      '46000',         '25',      '43500',
#             '70500',      '63909',      '22500',       '3520',      '32000',
#             '92000',      '97000',     '112000',      '59000',       '1200',
#            '107000',      '45500',      '66500',      '50400',        '400',
#             '63500',      '40950',       '1100',      '37968',      '58000',
#             '54000',      '43000',      '71000',     '125000',      '28000',
#             '77400',       '8500',     '102600',       '4700',       '3375',
#             '21000',      '81200',       '5400',     '170000',       '5800',
#                '12',       '1600',       '3600',       '5600',      '87250',
#            '105000',       '4300',       '4400',       '6710',      '26000',
#             '82000',     '110000',      '36000',      '10300',       '2400',
#              '7300',      '12150',       '9450',       '3400',      '17800',
#        '5000000000',      '84000',     '450000',      '19200',      '86000',
#          '60847.32',      '13500',       '6900',     '106000',      '35200',
#            '140000',      '20700',      '53500',      '66447',       '6300',
#             '82500',       '1250',       '3500',      '38500',        15000,
#             '74000',       '3250',      '89000'],
#       dtype='object')

# %%
df.Bonus_EUR=df.Bonus_EUR.astype('float64')

# %%
df.Bonus_EUR.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 19 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null float64
# Bonus_EUR                  1253 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(13)
# memory usage: 186.1+ KB

# %%
df['Number of vacation days'].value_counts().index
# Out:
# Index(['30', '28', '27', '25', '26', '24', '29', '20', '21', '22', '32', '31',
#        '35', '36', '23', '0', '40', '45', 'unlimited', '33', '14',
#        'unlimited ', 'Unlimited', '12', '15', '10', '39', '24 labour days',
#        '60', '50', '3', '23+', '~25', '16', '365', 'Unlimited ', '38', '5',
#        '99', '34', '1', '37', '37.5',
#        '30 in contract (but theoretically unlimited)', '(no idea)'],
#       dtype='object')

# %%
df['No_vac_days']=df['Number of vacation days'].str.split(' ').str[0]

# %%
df['No_vac_days'].value_counts().index
# Out:
# Index(['30', '28', '27', '25', '26', '24', '29', '20', '21', '31', '22', '32',
#        'unlimited', '35', '36', '23', '40', '0', '33', '45', 'Unlimited', '14',
#        '15', '12', '37.5', '5', '34', '60', '39', '38', '(no', '1', '365',
#        '50', '10', '23+', '~25', '99', '16', '37', '3'],
#       dtype='object')

# %%
df['No_vac_days'].replace({'unlimited':np.NaN,'Unlimited':np.NaN,'23+':23,'~25':25,'(no':np.NaN},inplace=True)

# %%
df['No_vac_days'].value_counts()
# Out:
# 30      489
# 28      233
# 27      102
# 25       91
# 26       71
# 24       68
# 29       24
# 20       13
# 21       10
# 22        8
# 31        8
# 32        8
# 36        5
# 35        5
# 0         4
# 40        4
# 23        4
# 33        3
# 14        3
# 45        3
# 12        2
# 15        2
# 38        1
# 23        1
# 3         1
# 60        1
# 39        1
# 37.5      1
# 37        1
# 1         1
# 5         1
# 50        1
# 10        1
# 25        1
# 34        1
# 16        1
# 99        1
# 365       1
# Name: No_vac_days, dtype: int64

# %%
df.No_vac_days=df.No_vac_days.astype('float64')

# %%
df.No_vac_days.fillna(df.No_vac_days.median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 20 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1243 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null float64
# Bonus_EUR                  1253 non-null float64
# No_vac_days                1253 non-null float64
# dtypes: datetime64[ns](1), float64(6), object(13)
# memory usage: 195.9+ KB

# %%
df['Age'].value_counts()
# Out:
# 30.0    110
# 33.0     94
# 32.0     94
# 28.0     87
# 31.0     87
# 29.0     86
# 35.0     82
# 34.0     74
# 36.0     60
# 26.0     59
# 27.0     58
# 38.0     48
# 37.0     44
# 25.0     42
# 40.0     31
# 39.0     28
# 24.0     28
# 42.0     20
# 41.0     14
# 23.0     12
# 45.0     11
# 43.0     10
# 22.0      8
# 44.0      8
# 46.0      8
# 48.0      4
# 47.0      3
# 49.0      2
# 56.0      2
# 54.0      2
# 59.0      1
# 65.0      1
# 66.0      1
# 53.0      1
# 50.0      1
# 51.0      1
# 21.0      1
# 20.0      1
# 52.0      1
# 69.0      1
# Name: Age, dtype: int64

# %%
df['Age'].value_counts().index
# Out:
# Float64Index([30.0, 33.0, 32.0, 28.0, 31.0, 29.0, 35.0, 34.0, 36.0, 26.0, 27.0,
#               38.0, 37.0, 25.0, 40.0, 39.0, 24.0, 42.0, 41.0, 23.0, 45.0, 43.0,
#               22.0, 44.0, 46.0, 48.0, 47.0, 49.0, 56.0, 54.0, 59.0, 65.0, 66.0,
#               53.0, 50.0, 51.0, 21.0, 20.0, 52.0, 69.0],
#              dtype='float64')

# %%
pd.options.display.max_seq_items=250

# %%
df['Gender'].value_counts().index
# Out:
# Index(['Male', 'Female', 'Diverse'], dtype='object')

# %%
df['Gender'].value_counts()
# Out:
# Male       1049
# Female      192
# Diverse       2
# Name: Gender, dtype: int64

# %%
df['Gender'].mode()
# Out:
# 0    Male
# dtype: object

# %%
df['Gender'].replace(to_replace=np.NaN,value='Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Age                         27
# Gender                       0
# City                         0
# Position                     6
# Total experience            16
# Experience in Germany       32
# Seniority level             12
# Main technology            127
# Annual Salary in EUR         0
# Bonus in EUR               424
# Number of vacation days     68
# Employment status           17
# Contract duration           29
# Main language at work       16
# Company type                25
# TE                           0
# ExpGermany                   0
# Bonus_EUR                    0
# No_vac_days                  0
# dtype: int64

# %%
df['City'].value_counts().index
# Out:
# Index(['Berlin', 'Munich', 'Frankfurt', 'Hamburg', 'Stuttgart', 'Cologne',
#        'Amsterdam', 'Stuttgart ', 'Karlsruhe', 'Moscow', 'Prague',
#        'Düsseldorf', 'Stockholm', 'Zurich', 'London', 'Düsseldorf ',
#        'Heidelberg', 'Helsinki', 'Nürnberg', 'Wolfsburg', 'Darmstadt',
#        'Boeblingen', 'Tallinn', 'Rome', 'Mannheim', 'Hannover', 'Bonn',
#        'Dusseldorf', 'Nuremberg', 'Rosenheim', 'Saint-Petersburg', 'Aachen',
#        'Leipzig', 'Paris', 'Barcelona', 'Vienna', 'Regensburg', 'Ingolstadt',
#        'Kyiv', 'Lisbon', 'Milan', 'Siegen', 'Eindhoven', 'Warsaw', 'Madrid',
#        'Ingolstadt ', 'Dortmund', 'Konstanz', 'Fr', 'Dublin ',
#        'Schleswig-Holstein', 'Würzburg', 'Tampere (Finland)', 'City in Russia',
#        'Moldova', 'Saarbrücken', 'Murnau am Staffelsee ', 'Cracovia', 'Ulm',
#        'Cambridge', 'Karlsruhe ', 'Mannheim ', 'Malta', 'Hildesheim ',
#        'Bucharest', 'Basel', 'Kempten', 'Walldorf', 'Prefer not to say',
#        'Luttich', 'Milano', 'Konstanz area', 'Friedrichshafen', 'Ansbach',
#        'Heidelberg ', 'Duesseldorf', 'Istanbul', 'Wroclaw', 'Tuttlingen',
#        'Brussels ', 'Cupertino', 'Koblenz', 'Erlangen', 'Den Haag', 'Lübeck',
#        'Dusseldurf', 'Bielefeld', 'Zürich', 'Nuremberg ', 'Samara',
#        'Innsbruck', 'Minsk', 'Marseille', 'Utrecht', 'Braunschweig ',
#        'Dresden', 'France', 'Cracow', 'warsaw', 'Copenhagen', 'Warsaw, Poland',
#        'Brunswick', 'Bodensee', 'Bölingen', 'Salzburg', 'Sevilla', 'NJ, USA',
#        'Heilbronn', 'Brussels', 'Jena', 'Krakow', 'Riga, Latvia', 'Paderborn',
#        'Köln', 'Hildesheim', 'Münster', 'Dublin', 'Sofia', 'Kiev'],
#       dtype='object')

# %%
df['City'].value_counts().index.sort_values()
# Out:
# Index(['Aachen', 'Amsterdam', 'Ansbach', 'Barcelona', 'Basel', 'Berlin',
#        'Bielefeld', 'Bodensee', 'Boeblingen', 'Bonn', 'Braunschweig ',
#        'Brunswick', 'Brussels', 'Brussels ', 'Bucharest', 'Bölingen',
#        'Cambridge', 'City in Russia', 'Cologne', 'Copenhagen', 'Cracovia',
#        'Cracow', 'Cupertino', 'Darmstadt', 'Den Haag', 'Dortmund', 'Dresden',
#        'Dublin', 'Dublin ', 'Duesseldorf', 'Dusseldorf', 'Dusseldurf',
#        'Düsseldorf', 'Düsseldorf ', 'Eindhoven', 'Erlangen', 'Fr', 'France',
#        'Frankfurt', 'Friedrichshafen', 'Hamburg', 'Hannover', 'Heidelberg',
#        'Heidelberg ', 'Heilbronn', 'Helsinki', 'Hildesheim', 'Hildesheim ',
#        'Ingolstadt', 'Ingolstadt ', 'Innsbruck', 'Istanbul', 'Jena',
#        'Karlsruhe', 'Karlsruhe ', 'Kempten', 'Kiev', 'Koblenz', 'Konstanz',
#        'Konstanz area', 'Krakow', 'Kyiv', 'Köln', 'Leipzig', 'Lisbon',
#        'London', 'Luttich', 'Lübeck', 'Madrid', 'Malta', 'Mannheim',
#        'Mannheim ', 'Marseille', 'Milan', 'Milano', 'Minsk', 'Moldova',
#        'Moscow', 'Munich', 'Murnau am Staffelsee ', 'Münster', 'NJ, USA',
#        'Nuremberg', 'Nuremberg ', 'Nürnberg', 'Paderborn', 'Paris', 'Prague',
#        'Prefer not to say', 'Regensburg', 'Riga, Latvia', 'Rome', 'Rosenheim',
#        'Saarbrücken', 'Saint-Petersburg', 'Salzburg', 'Samara',
#        'Schleswig-Holstein', 'Sevilla', 'Siegen', 'Sofia', 'Stockholm',
#        'Stuttgart', 'Stuttgart ', 'Tallinn', 'Tampere (Finland)', 'Tuttlingen',
#        'Ulm', 'Utrecht', 'Vienna', 'Walldorf', 'Warsaw', 'Warsaw, Poland',
#        'Wolfsburg', 'Wroclaw', 'Würzburg', 'Zurich', 'Zürich', 'warsaw'],
#       dtype='object')

# %%
df['City']=df['City'].str.strip()

# %%
df['City'].value_counts().index
# Out:
# Index(['Berlin', 'Munich', 'Frankfurt', 'Hamburg', 'Stuttgart', 'Cologne',
#        'Düsseldorf', 'Amsterdam', 'Karlsruhe', 'Prague', 'Moscow', 'Zurich',
#        'Stockholm', 'London', 'Heidelberg', 'Nürnberg', 'Mannheim', 'Helsinki',
#        'Rome', 'Hannover', 'Tallinn', 'Bonn', 'Darmstadt', 'Wolfsburg',
#        'Dusseldorf', 'Nuremberg', 'Boeblingen', 'Ingolstadt', 'Kyiv', 'Warsaw',
#        'Brussels', 'Aachen', 'Lisbon', 'Rosenheim', 'Leipzig',
#        'Saint-Petersburg', 'Paris', 'Madrid', 'Milan', 'Eindhoven', 'Vienna',
#        'Hildesheim', 'Barcelona', 'Dublin', 'Siegen', 'Regensburg',
#        'City in Russia', 'Walldorf', 'Basel', 'Moldova', 'Kempten', 'Ansbach',
#        'Malta', 'Prefer not to say', 'Duesseldorf', 'Luttich', 'Milano',
#        'Konstanz area', 'Konstanz', 'Schleswig-Holstein', 'Friedrichshafen',
#        'Cracovia', 'Dortmund', 'Cambridge', 'Fr', 'Ulm', 'Bucharest',
#        'Tampere (Finland)', 'Würzburg', 'NJ, USA', 'Istanbul', 'Bielefeld',
#        'Braunschweig', 'Koblenz', 'Erlangen', 'Den Haag', 'Lübeck',
#        'Dusseldurf', 'Murnau am Staffelsee', 'Saarbrücken', 'Tuttlingen',
#        'Samara', 'Innsbruck', 'Minsk', 'Marseille', 'Utrecht', 'Zürich',
#        'Dresden', 'Cupertino', 'Wroclaw', 'Warsaw, Poland', 'Krakow',
#        'Brunswick', 'Bodensee', 'Bölingen', 'Sevilla', 'Salzburg', 'Heilbronn',
#        'Copenhagen', 'Riga, Latvia', 'France', 'Paderborn', 'Köln', 'Münster',
#        'Sofia', 'Jena', 'warsaw', 'Cracow', 'Kiev'],
#       dtype='object')

# %%
df['City'].value_counts().index.sort_values()
# Out:
# Index(['Aachen', 'Amsterdam', 'Ansbach', 'Barcelona', 'Basel', 'Berlin',
#        'Bielefeld', 'Bodensee', 'Boeblingen', 'Bonn', 'Braunschweig',
#        'Brunswick', 'Brussels', 'Bucharest', 'Bölingen', 'Cambridge',
#        'City in Russia', 'Cologne', 'Copenhagen', 'Cracovia', 'Cracow',
#        'Cupertino', 'Darmstadt', 'Den Haag', 'Dortmund', 'Dresden', 'Dublin',
#        'Duesseldorf', 'Dusseldorf', 'Dusseldurf', 'Düsseldorf', 'Eindhoven',
#        'Erlangen', 'Fr', 'France', 'Frankfurt', 'Friedrichshafen', 'Hamburg',
#        'Hannover', 'Heidelberg', 'Heilbronn', 'Helsinki', 'Hildesheim',
#        'Ingolstadt', 'Innsbruck', 'Istanbul', 'Jena', 'Karlsruhe', 'Kempten',
#        'Kiev', 'Koblenz', 'Konstanz', 'Konstanz area', 'Krakow', 'Kyiv',
#        'Köln', 'Leipzig', 'Lisbon', 'London', 'Luttich', 'Lübeck', 'Madrid',
#        'Malta', 'Mannheim', 'Marseille', 'Milan', 'Milano', 'Minsk', 'Moldova',
#        'Moscow', 'Munich', 'Murnau am Staffelsee', 'Münster', 'NJ, USA',
#        'Nuremberg', 'Nürnberg', 'Paderborn', 'Paris', 'Prague',
#        'Prefer not to say', 'Regensburg', 'Riga, Latvia', 'Rome', 'Rosenheim',
#        'Saarbrücken', 'Saint-Petersburg', 'Salzburg', 'Samara',
#        'Schleswig-Holstein', 'Sevilla', 'Siegen', 'Sofia', 'Stockholm',
#        'Stuttgart', 'Tallinn', 'Tampere (Finland)', 'Tuttlingen', 'Ulm',
#        'Utrecht', 'Vienna', 'Walldorf', 'Warsaw', 'Warsaw, Poland',
#        'Wolfsburg', 'Wroclaw', 'Würzburg', 'Zurich', 'Zürich', 'warsaw'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 20 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1253 non-null object
# City                       1253 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null float64
# Bonus_EUR                  1253 non-null float64
# No_vac_days                1253 non-null float64
# dtypes: datetime64[ns](1), float64(6), object(13)
# memory usage: 195.9+ KB

# %%
df['City'].replace({'Dusseldorf':'Düsseldorf','Duesseldorf':'Düsseldorf','Dusseldurf':'Düsseldorf','Fr':'France','warsaw':'Warsaw','Warsaw, Poland':'Warsaw','Tampere (Finland)':'Tampere','NJ, USA':'NJ','Zürich':'Zürich','Zurich':'Zürich','Nürnberg':'Nürnberg','Nuremberg':'Nürnberg','City in Russia':np.NaN,'Prefer not to say':np.NaN,'Konstanz area':'Konstanz','np.NaN':np.NaN},inplace=True)

# %%
df['City'].value_counts()
# Out:
# Berlin                681
# Munich                236
# Frankfurt              44
# Hamburg                40
# Stuttgart              33
# Cologne                20
# Düsseldorf             15
# Amsterdam               9
# Karlsruhe               7
# Nürnberg                7
# Zürich                  6
# Moscow                  6
# Prague                  6
# London                  5
# Stockholm               5
# Heidelberg              5
# Helsinki                4
# Mannheim                4
# Warsaw                  4
# Wolfsburg               3
# Boeblingen              3
# Rome                    3
# Tallinn                 3
# Hannover                3
# Darmstadt               3
# Ingolstadt              3
# Bonn                    3
# France                  2
# Konstanz                2
# Hildesheim              2
#                      ...
# Lübeck                  1
# Walldorf                1
# Bielefeld               1
# Bölingen                1
# Brunswick               1
# Krakow                  1
# Bodensee                1
# Minsk                   1
# Ulm                     1
# Utrecht                 1
# Dresden                 1
# Braunschweig            1
# Tampere                 1
# Istanbul                1
# Den Haag                1
# Schleswig-Holstein      1
# Dortmund                1
# Tuttlingen              1
# Wroclaw                 1
# Friedrichshafen         1
# Erlangen                1
# Koblenz                 1
# Marseille               1
# Luttich                 1
# Innsbruck               1
# Salzburg                1
# Jena                    1
# Ansbach                 1
# Kempten                 1
# Basel                   1
# Name: City, Length: 98, dtype: int64

# %%
df['City'].value_counts().index
# Out:
# Index(['Berlin', 'Munich', 'Frankfurt', 'Hamburg', 'Stuttgart', 'Cologne',
#        'Düsseldorf', 'Amsterdam', 'Karlsruhe', 'Nürnberg', 'Zürich', 'Moscow',
#        'Prague', 'London', 'Stockholm', 'Heidelberg', 'Helsinki', 'Mannheim',
#        'Warsaw', 'Wolfsburg', 'Boeblingen', 'Rome', 'Tallinn', 'Hannover',
#        'Darmstadt', 'Ingolstadt', 'Bonn', 'France', 'Konstanz', 'Hildesheim',
#        'Brussels', 'Saint-Petersburg', 'Milan', 'Kyiv', 'Lisbon', 'Rosenheim',
#        'Dublin', 'Eindhoven', 'Siegen', 'Leipzig', 'Regensburg', 'Paris',
#        'Aachen', 'Vienna', 'Barcelona', 'Madrid', 'Moldova', 'Cracow', 'Köln',
#        'Sevilla', 'Cupertino', 'Paderborn', 'Kiev', 'Cambridge', 'Heilbronn',
#        'Riga, Latvia', 'NJ', 'Malta', 'Bucharest', 'Cracovia', 'Münster',
#        'Copenhagen', 'Sofia', 'Würzburg', 'Samara', 'Murnau am Staffelsee',
#        'Milano', 'Saarbrücken', 'Lübeck', 'Walldorf', 'Bielefeld', 'Bölingen',
#        'Brunswick', 'Krakow', 'Bodensee', 'Minsk', 'Ulm', 'Utrecht', 'Dresden',
#        'Braunschweig', 'Tampere', 'Istanbul', 'Den Haag', 'Schleswig-Holstein',
#        'Dortmund', 'Tuttlingen', 'Wroclaw', 'Friedrichshafen', 'Erlangen',
#        'Koblenz', 'Marseille', 'Luttich', 'Innsbruck', 'Salzburg', 'Jena',
#        'Ansbach', 'Kempten', 'Basel'],
#       dtype='object')

# %%
df['City'].value_counts().index.sort_values()
# Out:
# Index(['Aachen', 'Amsterdam', 'Ansbach', 'Barcelona', 'Basel', 'Berlin',
#        'Bielefeld', 'Bodensee', 'Boeblingen', 'Bonn', 'Braunschweig',
#        'Brunswick', 'Brussels', 'Bucharest', 'Bölingen', 'Cambridge',
#        'Cologne', 'Copenhagen', 'Cracovia', 'Cracow', 'Cupertino', 'Darmstadt',
#        'Den Haag', 'Dortmund', 'Dresden', 'Dublin', 'Düsseldorf', 'Eindhoven',
#        'Erlangen', 'France', 'Frankfurt', 'Friedrichshafen', 'Hamburg',
#        'Hannover', 'Heidelberg', 'Heilbronn', 'Helsinki', 'Hildesheim',
#        'Ingolstadt', 'Innsbruck', 'Istanbul', 'Jena', 'Karlsruhe', 'Kempten',
#        'Kiev', 'Koblenz', 'Konstanz', 'Krakow', 'Kyiv', 'Köln', 'Leipzig',
#        'Lisbon', 'London', 'Luttich', 'Lübeck', 'Madrid', 'Malta', 'Mannheim',
#        'Marseille', 'Milan', 'Milano', 'Minsk', 'Moldova', 'Moscow', 'Munich',
#        'Murnau am Staffelsee', 'Münster', 'NJ', 'Nürnberg', 'Paderborn',
#        'Paris', 'Prague', 'Regensburg', 'Riga, Latvia', 'Rome', 'Rosenheim',
#        'Saarbrücken', 'Saint-Petersburg', 'Salzburg', 'Samara',
#        'Schleswig-Holstein', 'Sevilla', 'Siegen', 'Sofia', 'Stockholm',
#        'Stuttgart', 'Tallinn', 'Tampere', 'Tuttlingen', 'Ulm', 'Utrecht',
#        'Vienna', 'Walldorf', 'Warsaw', 'Wolfsburg', 'Wroclaw', 'Würzburg',
#        'Zürich'],
#       dtype='object')

# %%
df['Employment status'].value_counts()
# Out:
# Full-time employee                                                                 1190
# Self-employed (freelancer)                                                           28
# Part-time employee                                                                    8
# Founder                                                                               3
# full-time, but 32 hours per week (it was my request, I'm a student)                   1
# Company Director                                                                      1
# Working Student                                                                       1
# Full-time position, part-time position, & self-employed (freelancing, tutoring)       1
# Werkstudent                                                                           1
# Intern                                                                                1
# working student                                                                       1
# Name: Employment status, dtype: int64

# %%
df['Employment status'].value_counts().index
# Out:
# Index(['Full-time employee', 'Self-employed (freelancer)',
#        'Part-time employee', 'Founder',
#        'full-time, but 32 hours per week (it was my request, I'm a student)',
#        'Company Director', 'Working Student',
#        'Full-time position, part-time position, & self-employed (freelancing, tutoring)',
#        'Werkstudent', 'Intern', 'working student'],
#       dtype='object')

# %%
df['Employment status'].value_counts().index.sort_values()
# Out:
# Index(['Company Director', 'Founder', 'Full-time employee',
#        'Full-time position, part-time position, & self-employed (freelancing, tutoring)',
#        'Intern', 'Part-time employee', 'Self-employed (freelancer)',
#        'Werkstudent', 'Working Student',
#        'full-time, but 32 hours per week (it was my request, I'm a student)',
#        'working student'],
#       dtype='object')

# %%
df['Employment status'].str.split(' ').str[0]
# Out:
# 0           Full-time
# 1           Full-time
# 2       Self-employed
# 3           Full-time
# 4           Full-time
# 5           Full-time
# 6           Full-time
# 7           Full-time
# 8           Full-time
# 9           Full-time
# 10          Full-time
# 11      Self-employed
# 12          Full-time
# 13          Full-time
# 14          Full-time
# 15          Full-time
# 16          Full-time
# 17          Full-time
# 18          Full-time
# 19          Full-time
# 20          Full-time
# 21          Full-time
# 22          Full-time
# 23          Full-time
# 24          Full-time
# 25          Full-time
# 26          Full-time
# 27          Full-time
# 28          Full-time
# 29          Full-time
#             ...
# 1223    Self-employed
# 1224        Full-time
# 1225        Full-time
# 1226        Full-time
# 1227        Full-time
# 1228        Full-time
# 1229        Full-time
# 1230        Full-time
# 1231              NaN
# 1232    Self-employed
# 1233        Full-time
# 1234        Full-time
# 1235        Full-time
# 1236        Full-time
# 1237        Full-time
# 1238        Full-time
# 1239        Full-time
# 1240              NaN
# 1241        Full-time
# 1242        Full-time
# 1243              NaN
# 1244        Full-time
# 1245        Full-time
# 1246        Full-time
# 1247        Full-time
# 1248        Full-time
# 1249        Full-time
# 1250        Full-time
# 1251        Full-time
# 1252        Full-time
# Name: Employment status, Length: 1253, dtype: object

# %%
df['Employment status']=df['Employment status'].str.split(' ').str[0]

# %%
df['Employment status'].value_counts()
# Out:
# Full-time        1191
# Self-employed      28
# Part-time           8
# Founder             3
# Company             1
# Working             1
# full-time,          1
# working             1
# Werkstudent         1
# Intern              1
# Name: Employment status, dtype: int64

# %%
df['Employment status'].value_counts().index.sort_values()
# Out:
# Index(['Company', 'Founder', 'Full-time', 'Intern', 'Part-time',
#        'Self-employed', 'Werkstudent', 'Working', 'full-time,', 'working'],
#       dtype='object')

# %%
df['Employment status'].replace({'full-time':'Full-time','working':'Working','Werkstudent':'Workstudent'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 20 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1253 non-null object
# City                       1251 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority level            1241 non-null object
# Main technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment status          1236 non-null object
# Contract duration          1224 non-null object
# Main language at work      1237 non-null object
# Company type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null float64
# Bonus_EUR                  1253 non-null float64
# No_vac_days                1253 non-null float64
# dtypes: datetime64[ns](1), float64(6), object(13)
# memory usage: 195.9+ KB

# %%
df['Position '].value_counts()
# Out:
# Software Engineer                         387
# Backend Developer                         174
# Data Scientist                            110
# Frontend Developer                         89
# QA Engineer                                71
# DevOps                                     57
# Mobile Developer                           53
# ML Engineer                                42
# Product Manager                            39
# Data Engineer                              25
# Designer (UI/UX)                           16
# Engineering Manager                        10
# Data Analyst                                8
# CTO                                         5
# Software Architect                          4
# Project Manager                             4
# Fullstack Developer                         4
# SRE                                         4
# Business Analyst                            3
# Consultant                                  3
# Hardware Engineer                           3
# Team Lead                                   3
# Data Analyst                                2
# Head of Engineering                         2
# IT Manager                                  2
# Product Analyst                             2
# Solutions Architect                         2
# Support Engineer                            2
# Security Engineer                           2
# SW Architect                                1
#                                          ...
# Dana Analyst                                1
# Manager                                     1
# Network Engineer                            1
# DataOps Team Lead                           1
# Computational linguist                      1
# Testmanager                                 1
# System Administrator                        1
# Software Developer in Test                  1
# Senior Scrum Master (RTE)                   1
# IT Spezialist                               1
# Presales Engineer                           1
# HiWi                                        1
# Cloud Engineer                              1
# Architect                                   1
# Project manager                             1
# Data Center Manager                         1
# Solutions architect                         1
# Firmware Engineer                           1
# Recruiter                                   1
# Test manager                                1
# Researcher/ Consumer Insights Analyst       1
# Banker                                      1
# data engineer                               1
# iOS Developer                               1
# Data analyst                                1
# Network Administrator                       1
# BI Consultant SAP/ Data Engineer            1
# Technical account manager                   1
# Head of IT                                  1
# Lead Software Developer                     1
# Name: Position , Length: 148, dtype: int64

# %%
df['Position '].value_counts().index
# Out:
# Index(['Software Engineer', 'Backend Developer', 'Data Scientist',
#        'Frontend Developer', 'QA Engineer', 'DevOps', 'Mobile Developer',
#        'ML Engineer', 'Product Manager', 'Data Engineer', 'Designer (UI/UX)',
#        'Engineering Manager', 'Data Analyst', 'CTO', 'Software Architect',
#        'Project Manager', 'Fullstack Developer', 'SRE', 'Business Analyst',
#        'Consultant', 'Hardware Engineer', 'Team Lead', 'Data Analyst ',
#        'Head of Engineering', 'IT Manager', 'Product Analyst',
#        'Solutions Architect', 'Support Engineer', 'Security Engineer',
#        'SW Architect', 'C/C++/Java developer', 'BI Consultant',
#        'Tech recruiting', 'Student, Software Developer, Data Engineer',
#        'Freelance AI lead / advisor', 'SAP Consultant', 'Graphic Designer',
#        'Robotics Engineer', 'Analyst', 'BI Analyst ', 'Big Data Engineer',
#        'Tech Leader', 'Technical project manager', 'AI Management',
#        'Staff Engineer', 'Engineering Team Lead', 'Solution Architect',
#        'Team lead', 'Tech Lead', 'Teamlead', 'DatabEngineer',
#        'Cloud Architect', 'Business Development Manager Operations ',
#        'Tech Lead / Full-Stack', 'Full-Stack Developer',
#        'Consultant Data Analytics', 'IT Operations Manager',
#        'Security Manager', 'Data Science Manager', 'Software tester ',
#        'Software Sales', 'QA Manager', 'XR Developer', 'Team Manager',
#        'Application Consultant', 'Project manager ', 'Localization producer',
#        'Product Management Praktikant', 'Architect', 'Senior Data Engineer',
#        'Reporting Engineer', 'BI IT Consultant', 'Agile Coach', 'Sales ',
#        'Analytics engineer', 'VP Engineering', 'Security engineer', 'QA Lead',
#        'Stuttgart', 'Program Manager',
#        'Fullstack engineer, ну или Software engineer', 'Account Managet',
#        'SAP Developer', 'Rentner', 'Beikoch', 'Head of IT',
#        'Chief Research Officer', 'working student (QA)', 'Technical Lead',
#        'It Consulting ', 'Head of BI', 'Testautomation', 'Marketing Analyst',
#        'technical business analyst', 'Lead Developer',
#        'Director of Engineering', 'support engineer',
#        'DB developer/Data analyst', 'Researcher', 'QA Manager ',
#        'Systemadministrator', 'ERP Consultant', 'DevOps Manager',
#        'agile master ', 'computer vision researcher', 'DBA',
#        'SAP BW Senior Consultant ', 'Consultant ', 'Professor',
#        'Senior Network&Security Eng.', 'Embedded Software Engineer',
#        'Data architect', 'BI Developer / Data Engineer',
#        'Senior Program Manager', 'Software Architekt', 'Scrum Master',
#        'Manager ', 'Engineering manager', 'Dana Analyst', 'Manager',
#        'Network Engineer ', 'DataOps Team Lead', 'Computational linguist',
#        'Testmanager', 'System Administrator', 'Software Developer in Test',
#        'Senior Scrum Master (RTE)', 'IT Spezialist', 'Presales Engineer ',
#        'HiWi', 'Cloud Engineer', 'Architect ', 'Project manager',
#        'Data Center Manager', 'Solutions architect', 'Firmware Engineer',
#        'Recruiter', 'Test manager', 'Researcher/ Consumer Insights Analyst ',
#        'Banker', 'data engineer', 'iOS Developer', 'Data analyst ',
#        'Network Administrator', 'BI Consultant SAP/ Data Engineer',
#        'Technical account manager ', 'Head of IT ', 'Lead Software Developer'],
#       dtype='object')

# %%
df['Position '].value_counts().index.sort_values()
# Out:
# Index(['AI Management', 'Account Managet', 'Agile Coach', 'Analyst',
#        'Analytics engineer', 'Application Consultant', 'Architect',
#        'Architect ', 'BI Analyst ', 'BI Consultant',
#        'BI Consultant SAP/ Data Engineer', 'BI Developer / Data Engineer',
#        'BI IT Consultant', 'Backend Developer', 'Banker', 'Beikoch',
#        'Big Data Engineer', 'Business Analyst',
#        'Business Development Manager Operations ', 'C/C++/Java developer',
#        'CTO', 'Chief Research Officer', 'Cloud Architect', 'Cloud Engineer',
#        'Computational linguist', 'Consultant', 'Consultant ',
#        'Consultant Data Analytics', 'DB developer/Data analyst', 'DBA',
#        'Dana Analyst', 'Data Analyst', 'Data Analyst ', 'Data Center Manager',
#        'Data Engineer', 'Data Science Manager', 'Data Scientist',
#        'Data analyst ', 'Data architect', 'DataOps Team Lead', 'DatabEngineer',
#        'Designer (UI/UX)', 'DevOps', 'DevOps Manager',
#        'Director of Engineering', 'ERP Consultant',
#        'Embedded Software Engineer', 'Engineering Manager',
#        'Engineering Team Lead', 'Engineering manager', 'Firmware Engineer',
#        'Freelance AI lead / advisor', 'Frontend Developer',
#        'Full-Stack Developer', 'Fullstack Developer',
#        'Fullstack engineer, ну или Software engineer', 'Graphic Designer',
#        'Hardware Engineer', 'Head of BI', 'Head of Engineering', 'Head of IT',
#        'Head of IT ', 'HiWi', 'IT Manager', 'IT Operations Manager',
#        'IT Spezialist', 'It Consulting ', 'Lead Developer',
#        'Lead Software Developer', 'Localization producer', 'ML Engineer',
#        'Manager', 'Manager ', 'Marketing Analyst', 'Mobile Developer',
#        'Network Administrator', 'Network Engineer ', 'Presales Engineer ',
#        'Product Analyst', 'Product Management Praktikant', 'Product Manager',
#        'Professor', 'Program Manager', 'Project Manager', 'Project manager',
#        'Project manager ', 'QA Engineer', 'QA Lead', 'QA Manager',
#        'QA Manager ', 'Recruiter', 'Rentner', 'Reporting Engineer',
#        'Researcher', 'Researcher/ Consumer Insights Analyst ',
#        'Robotics Engineer', 'SAP BW Senior Consultant ', 'SAP Consultant',
#        'SAP Developer', 'SRE', 'SW Architect', 'Sales ', 'Scrum Master',
#        'Security Engineer', 'Security Manager', 'Security engineer',
#        'Senior Data Engineer', 'Senior Network&Security Eng.',
#        'Senior Program Manager', 'Senior Scrum Master (RTE)',
#        'Software Architect', 'Software Architekt',
#        'Software Developer in Test', 'Software Engineer', 'Software Sales',
#        'Software tester ', 'Solution Architect', 'Solutions Architect',
#        'Solutions architect', 'Staff Engineer',
#        'Student, Software Developer, Data Engineer', 'Stuttgart',
#        'Support Engineer', 'System Administrator', 'Systemadministrator',
#        'Team Lead', 'Team Manager', 'Team lead', 'Teamlead', 'Tech Lead',
#        'Tech Lead / Full-Stack', 'Tech Leader', 'Tech recruiting',
#        'Technical Lead', 'Technical account manager ',
#        'Technical project manager', 'Test manager', 'Testautomation',
#        'Testmanager', 'VP Engineering', 'XR Developer', 'agile master ',
#        'computer vision researcher', 'data engineer', 'iOS Developer',
#        'support engineer', 'technical business analyst',
#        'working student (QA)'],
#       dtype='object')

# %%
df['Position '].replace({'Dana Analyst':'Data Analyst','Data Analyst ':'Data Analyst','Data Analyst':'Data Analyst','ну или Software engineer':'Software engineer','Software Architekt':'Software Architect','data engineer' :'Data Engineer','Consultant ':'Consultant'},inplace=True)

# %%
df['Position '].replace({'Dana Analyst':'Data Analyst','Data Analyst ':'Data Analyst','Data Analyst':'Data Analyst','ну или Software engineer':'Software engineer','Software Architekt':'Software Architect','data engineer':'Data Engineer','Consultant ':'Consultant'},inplace=True)

# %%
df['Position '].value_counts().index.sort_values()
# Out:
# Index(['AI Management', 'Account Managet', 'Agile Coach', 'Analyst',
#        'Analytics engineer', 'Application Consultant', 'Architect',
#        'Architect ', 'BI Analyst ', 'BI Consultant',
#        'BI Consultant SAP/ Data Engineer', 'BI Developer / Data Engineer',
#        'BI IT Consultant', 'Backend Developer', 'Banker', 'Beikoch',
#        'Big Data Engineer', 'Business Analyst',
#        'Business Development Manager Operations ', 'C/C++/Java developer',
#        'CTO', 'Chief Research Officer', 'Cloud Architect', 'Cloud Engineer',
#        'Computational linguist', 'Consultant', 'Consultant Data Analytics',
#        'DB developer/Data analyst', 'DBA', 'Data Analyst',
#        'Data Center Manager', 'Data Engineer', 'Data Science Manager',
#        'Data Scientist', 'Data analyst ', 'Data architect',
#        'DataOps Team Lead', 'DatabEngineer', 'Designer (UI/UX)', 'DevOps',
#        'DevOps Manager', 'Director of Engineering', 'ERP Consultant',
#        'Embedded Software Engineer', 'Engineering Manager',
#        'Engineering Team Lead', 'Engineering manager', 'Firmware Engineer',
#        'Freelance AI lead / advisor', 'Frontend Developer',
#        'Full-Stack Developer', 'Fullstack Developer',
#        'Fullstack engineer, ну или Software engineer', 'Graphic Designer',
#        'Hardware Engineer', 'Head of BI', 'Head of Engineering', 'Head of IT',
#        'Head of IT ', 'HiWi', 'IT Manager', 'IT Operations Manager',
#        'IT Spezialist', 'It Consulting ', 'Lead Developer',
#        'Lead Software Developer', 'Localization producer', 'ML Engineer',
#        'Manager', 'Manager ', 'Marketing Analyst', 'Mobile Developer',
#        'Network Administrator', 'Network Engineer ', 'Presales Engineer ',
#        'Product Analyst', 'Product Management Praktikant', 'Product Manager',
#        'Professor', 'Program Manager', 'Project Manager', 'Project manager',
#        'Project manager ', 'QA Engineer', 'QA Lead', 'QA Manager',
#        'QA Manager ', 'Recruiter', 'Rentner', 'Reporting Engineer',
#        'Researcher', 'Researcher/ Consumer Insights Analyst ',
#        'Robotics Engineer', 'SAP BW Senior Consultant ', 'SAP Consultant',
#        'SAP Developer', 'SRE', 'SW Architect', 'Sales ', 'Scrum Master',
#        'Security Engineer', 'Security Manager', 'Security engineer',
#        'Senior Data Engineer', 'Senior Network&Security Eng.',
#        'Senior Program Manager', 'Senior Scrum Master (RTE)',
#        'Software Architect', 'Software Developer in Test', 'Software Engineer',
#        'Software Sales', 'Software tester ', 'Solution Architect',
#        'Solutions Architect', 'Solutions architect', 'Staff Engineer',
#        'Student, Software Developer, Data Engineer', 'Stuttgart',
#        'Support Engineer', 'System Administrator', 'Systemadministrator',
#        'Team Lead', 'Team Manager', 'Team lead', 'Teamlead', 'Tech Lead',
#        'Tech Lead / Full-Stack', 'Tech Leader', 'Tech recruiting',
#        'Technical Lead', 'Technical account manager ',
#        'Technical project manager', 'Test manager', 'Testautomation',
#        'Testmanager', 'VP Engineering', 'XR Developer', 'agile master ',
#        'computer vision researcher', 'iOS Developer', 'support engineer',
#        'technical business analyst', 'working student (QA)'],
#       dtype='object')

# %%
df.rename(columns ={'Main language at work':'Main_language_work ','Seniority level':'Seniority_level','Main technology':'Main_technology','Company type':'Company_type','Employment status':'Employment_status' },inplace=True)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ', 'Total experience',
#        'Experience in Germany', 'Seniority_level', 'Main_technology',
#        'Annual Salary in EUR', 'Bonus in EUR', 'Number of vacation days',
#        'Employment_status', 'Contract duration', 'Main_language_work ',
#        'Company_type', 'TE', 'ExpGermany', 'Bonus_EUR', 'No_vac_days'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 20 columns):
# Timestamp                  1253 non-null datetime64[ns]
# Age                        1226 non-null float64
# Gender                     1253 non-null object
# City                       1251 non-null object
# Position                   1247 non-null object
# Total experience           1237 non-null object
# Experience in Germany      1221 non-null object
# Seniority_level            1241 non-null object
# Main_technology            1126 non-null object
# Annual Salary in EUR       1253 non-null float64
# Bonus in EUR               829 non-null object
# Number of vacation days    1185 non-null object
# Employment_status          1236 non-null object
# Contract duration          1224 non-null object
# Main_language_work         1237 non-null object
# Company_type               1228 non-null object
# TE                         1253 non-null float64
# ExpGermany                 1253 non-null float64
# Bonus_EUR                  1253 non-null float64
# No_vac_days                1253 non-null float64
# dtypes: datetime64[ns](1), float64(6), object(13)
# memory usage: 195.9+ KB

# %%
df['Main_technology'].value_counts()
# Out:
# Java                                       184
# Python                                     164
# PHP                                         56
# C++                                         38
# JavaScript                                  34
# Javascript                                  31
# C#                                          30
# python                                      26
# Swift                                       24
# Scala                                       24
# Go                                          23
# Kotlin                                      22
# Python                                      21
# Ruby                                        19
# SQL                                         14
# TypeScript                                  14
# .NET                                        13
# JS                                          12
# iOS                                         10
# C                                           10
# R                                            9
# java                                         9
# Android                                      8
# javascript                                   8
# Typescript                                   8
# php                                          8
# Kubernetes                                   7
# .net                                         7
# JavaScript                                   6
# Javascript / Typescript                      6
#                                           ...
# Pascal, VB.NET, C#                           1
# UML                                          1
# Java/Scala                                   1
# Charles                                      1
# Python, cloud computing                      1
# Linux                                        1
# PL/SQL                                       1
# Ml/Python                                    1
# Go, PHP, SQL                                 1
# Pyrhon                                       1
# Azure, SAP                                   1
# SAP ABAP                                     1
# Haskell                                      1
# Java, JS                                     1
# React / JavaScript                           1
# AWS, GCP, Python,K8s                         1
# Js, reactJS                                  1
# Network                                      1
# Tricentis Tosca                              1
# SAS,SQL,Python                               1
# c/c++                                        1
# Kuberenetes, Openstack                       1
# Python + SQL                                 1
# Qlik                                         1
# Oracle                                       1
# jenkins bash                                 1
# Business Development Manager Operation       1
# NLP, Python                                  1
# ML                                           1
# Agile                                        1
# Name: Main_technology, Length: 256, dtype: int64

# %%
df['Main_technology'].value_counts().index.sort_values()
# Out:
# Index(['-', '--', '.NET', '.Net', '.Net, Angular', '.net',
#        '.net, c++, spss, embeddded', 'ABAP', 'AI', 'AWS',
#        ...
#        'ruby on rails', 'scala', 'several', 'spark', 'sql', 'swift',
#        'typescript', 'yaml', 'Офмф', 'С#'],
#       dtype='object', length=256)

# %%
df['Main_technology'].replace({'-':'np.NaN','--':'np.NaN','.Net':'.NET','.Net':'.NET','.net':'.NET','.net':'.NET','Офмф':'np.NaN'},inplace=True)

# %%
Age = np.where(df['Age'].isnull(),21+df['TE'],df['Age'])

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Univariate

# %%
df.TE.describe()
# Out:
# count    1253.000000
# mean        8.766640
# std         5.307046
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%        12.000000
# max        40.000000
# Name: TE, dtype: float64

# %%
sns.histplot(x='TE',data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-2e42edd8ab65> in <module>()
# ----> 1 sns.histplot(x='TE',data=df)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
sns.boxplot(x='TE', data=df)

# %%
df.ExpGermany.describe()
# Out:
# count    1253.000000
# mean        3.620511
# std         3.635562
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        30.000000
# Name: ExpGermany, dtype: float64

# %%
sns.histplot(x='ExpGermany', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-864290355c07> in <module>()
# ----> 1 sns.histplot(x='ExpGermany', data=df)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
sns.boxplot(x='ExpGermany', data=df)

# %%
df.Bonus_EUR.describe()
# Out:
# count    1.253000e+03
# mean     4.004581e+06
# std      1.412516e+08
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      9.450000e+03
# max      5.000000e+09
# Name: Bonus_EUR, dtype: float64

# %%
sns.histplot(x='No_vac_days', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-b0e1fba0f933> in <module>()
# ----> 1 sns.histplot(x='No_vac_days', data=df)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
df['City'].value_counts()
# Out:
# Berlin                681
# Munich                236
# Frankfurt              44
# Hamburg                40
# Stuttgart              33
# Cologne                20
# Düsseldorf             15
# Amsterdam               9
# Karlsruhe               7
# Nürnberg                7
# Zürich                  6
# Moscow                  6
# Prague                  6
# London                  5
# Stockholm               5
# Heidelberg              5
# Helsinki                4
# Mannheim                4
# Warsaw                  4
# Wolfsburg               3
# Boeblingen              3
# Rome                    3
# Tallinn                 3
# Hannover                3
# Darmstadt               3
# Ingolstadt              3
# Bonn                    3
# France                  2
# Konstanz                2
# Hildesheim              2
#                      ...
# Lübeck                  1
# Walldorf                1
# Bielefeld               1
# Bölingen                1
# Brunswick               1
# Krakow                  1
# Bodensee                1
# Minsk                   1
# Ulm                     1
# Utrecht                 1
# Dresden                 1
# Braunschweig            1
# Tampere                 1
# Istanbul                1
# Den Haag                1
# Schleswig-Holstein      1
# Dortmund                1
# Tuttlingen              1
# Wroclaw                 1
# Friedrichshafen         1
# Erlangen                1
# Koblenz                 1
# Marseille               1
# Luttich                 1
# Innsbruck               1
# Salzburg                1
# Jena                    1
# Ansbach                 1
# Kempten                 1
# Basel                   1
# Name: City, Length: 98, dtype: int64

# %%
plt.subplots(figsize=(15,60))
sns.countplot(y='City', data=df, order=df['City'].value_counts().index.sort_values())

# %%
df['Position '].value_counts()
# Out:
# Software Engineer                         387
# Backend Developer                         174
# Data Scientist                            110
# Frontend Developer                         89
# QA Engineer                                71
# DevOps                                     57
# Mobile Developer                           53
# ML Engineer                                42
# Product Manager                            39
# Data Engineer                              26
# Designer (UI/UX)                           16
# Data Analyst                               11
# Engineering Manager                        10
# Software Architect                          5
# CTO                                         5
# Consultant                                  4
# Fullstack Developer                         4
# SRE                                         4
# Project Manager                             4
# Business Analyst                            3
# Hardware Engineer                           3
# Team Lead                                   3
# Head of Engineering                         2
# Solutions Architect                         2
# Product Analyst                             2
# Security Engineer                           2
# Support Engineer                            2
# IT Manager                                  2
# QA Lead                                     1
# SW Architect                                1
#                                          ...
# Architect                                   1
# QA Manager                                  1
# Manager                                     1
# Network Engineer                            1
# DataOps Team Lead                           1
# Computational linguist                      1
# Testmanager                                 1
# System Administrator                        1
# Software Developer in Test                  1
# Senior Scrum Master (RTE)                   1
# IT Spezialist                               1
# Presales Engineer                           1
# HiWi                                        1
# Cloud Engineer                              1
# Project manager                             1
# Engineering manager                         1
# Data Center Manager                         1
# Solutions architect                         1
# Firmware Engineer                           1
# Recruiter                                   1
# Test manager                                1
# Researcher/ Consumer Insights Analyst       1
# Banker                                      1
# iOS Developer                               1
# Data analyst                                1
# Network Administrator                       1
# BI Consultant SAP/ Data Engineer            1
# Technical account manager                   1
# Head of IT                                  1
# Lead Software Developer                     1
# Name: Position , Length: 143, dtype: int64

# %%
plt.subplots(figsize=(15,60))
sns.countplot(y='Position ', data=df, order=df['Position '].value_counts().index.sort_values())

# %%
df['Seniority_level'].value_counts()
# Out:
# Senior                                       565
# Middle                                       366
# Lead                                         166
# Junior                                        79
# Head                                          44
# Principal                                      3
# No level                                       1
# Key                                            1
# Intern                                         1
# Self employed                                  1
# intern                                         1
# VP                                             1
# Working Student                                1
# C-Level                                        1
# Manager                                        1
# Student                                        1
# C-level executive manager                      1
# student                                        1
# Director                                       1
# no idea, there are no ranges in the firm       1
# Entry level                                    1
# Work Center Manager                            1
# No level                                       1
# CTO                                            1
# Name: Seniority_level, dtype: int64

# %%
plt.subplots(figsize=(6,15))
sns.countplot(y='Seniority_level', data=df, order=df['Seniority_level'].value_counts().index.sort_values())

# %%
df['Main_technology'].value_counts().index.sort_values()
# Out:
# Index(['.NET', '.Net, Angular', '.net, c++, spss, embeddded', 'ABAP', 'AI',
#        'AWS', 'AWS, GCP, Python,K8s', 'Agile', 'Android', 'Android/Kotlin',
#        ...
#        'python, scala', 'ruby on rails', 'scala', 'several', 'spark', 'sql',
#        'swift', 'typescript', 'yaml', 'С#'],
#       dtype='object', length=252)

# %%
plt.subplots(figsize=(6,55))
sns.countplot(y='Main_technology', data=df, order=df['Main_technology'].value_counts().index.sort_values())

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ## Numerical-Categorical

# %%
plt.subplots(figsize=(45,20))
sns.boxplot(x='Seniority_level', y='TE', data=df)

# %%
plt.subplots(figsize=(8,25))
sns.boxplot(y='Position ', x='TE', data=df)

# %%
df_num = df.select_dtypes(exclude='object')

# %%
num_list = list(df_num.columns)
num_list
# Out:
# ['Timestamp',
#  'Age',
#  'Annual Salary in EUR',
#  'TE',
#  'ExpGermany',
#  'Bonus_EUR',
#  'No_vac_days']

# %%
num_list.remove('Timestamp')

# %%
num_list
# Out:
# ['Age', 'Annual Salary in EUR', 'TE', 'ExpGermany', 'Bonus_EUR', 'No_vac_days']

# %%
num_list
# Out:
# ['Age', 'Annual Salary in EUR', 'TE', 'ExpGermany', 'Bonus_EUR', 'No_vac_days']

# %%
sns.pairplot(vars=num_list, data=df)

# %% [markdown]
# ## Categorical-Categorical

# %%
plt.subplots(figsize=(25,25))
sns.countplot(y='Seniority_level', hue='Position ', data=df, order= df.Seniority_level.value_counts().index)
